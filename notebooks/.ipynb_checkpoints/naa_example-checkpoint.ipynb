# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.signal import find_peaks
from naa import load_spectrum, fit_spectrum, fit_gaus, plot_spectrum
import csv

# %%
# write a function to compute the rate R as a function of
# cross section, N_0 and the total flux
def Rate(
    n_0:    int,
    phi_total: float, 
    sigma_eff: float
):
    pass

# %%
# write a function to compute <N(t_rad)> from the rate,
# decay constant, and radiation time.
def N_rad(
    rate:   float,
    lambda_decay:   float, 
    t_rad:  float
):
    pass

# %%
# write a function to compute <N(t_dead)> from
# <N(t_rad)>, the decay constant and t_dead.
def N_dead(
    n_rad:  float, 
    lambda_decay:   float, 
    t_dead: float
):
    pass

# %%
# write a function to compute <N_counts> from <N(t_dead)>,
# the decay constant and the counting time.
def N_counts(
    n_dead: float, 
    lambda_decay:   float, 
    t_count:    float
):
    pass

# %%
# write a function to compute the flux as a function
# of the decay constant, t_rar, t_dead, t_count,
# the flux, cross section, efficiency, bin probability and 
# the total detected counts in a specific energy bin
def flux(
    lambda_decay:   float, 
    t_rad:  float, 
    t_dead: float, 
    t_count:    float, 
    phi_total:  float, 
    sigma_eff:  float, 
    efficiency: float, 
    probability:    float, 
    n_det:  float
):
    pass

# %%
energies, counts = load_spectrum("../examples/NaCl_2022_1.TKA")
parameters, integral, fit_energies, fit_counts = fit_gaus(energies, counts, 1360, 1370, 1380)
plot_spectrum(energies, counts, fit_energies, fit_counts, integral)
# Out:
# 5598.810348397277
